# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
df = pd.read_csv("C:\\Datasets\\Nasa\\nasa.csv")
df.head()
# Out:
#    Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0           3703080  3703080                21.6            0.127220
# 1           3723955  3723955                21.3            0.146068
# 2           2446862  2446862                20.3            0.231502
# 3           3092506  3092506                27.4            0.008801
# 4           3514799  3514799                21.6            0.127220
#
#    Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 0            0.284472         127.219879         284.472297
# 1            0.326618         146.067964         326.617897
# 2            0.517654         231.502122         517.654482
# 3            0.019681           8.801465          19.680675
# 4            0.284472         127.219879         284.472297
#
#    Est Dia in Miles(min)  Est Dia in Miles(max)  Est Dia in Feet(min)  ...  \
# 0               0.079051               0.176763            417.388066  ...
# ...

# %%
df.isnull().sum()
# Out:
# Neo Reference ID                0
# Name                            0
# Absolute Magnitude              0
# Est Dia in KM(min)              0
# Est Dia in KM(max)              0
# Est Dia in M(min)               0
# Est Dia in M(max)               0
# Est Dia in Miles(min)           0
# Est Dia in Miles(max)           0
# Est Dia in Feet(min)            0
# Est Dia in Feet(max)            0
# Close Approach Date             0
# Epoch Date Close Approach       0
# Relative Velocity km per sec    0
# Relative Velocity km per hr     0
# Miles per hour                  0
# Miss Dist.(Astronomical)        0
# Miss Dist.(lunar)               0
# Miss Dist.(kilometers)          0
# Miss Dist.(miles)               0
# Orbiting Body                   0
# Orbit ID                        0
# Orbit Determination Date        0
# Orbit Uncertainity              0
# Minimum Orbit Intersection      0
# Jupiter Tisserand Invariant     0
# Epoch Osculation                0
# ...

# %%
df['Close Approach Date'] = pd.to_datetime(df['Close Approach Date'])
df['Close Approach Date'].head()
# Out:
# 0   1995-01-01
# 1   1995-01-01
# 2   1995-01-08
# 3   1995-01-15
# 4   1995-01-15
# Name: Close Approach Date, dtype: datetime64[ns]

# %%
df.describe()
# Out:
#        Neo Reference ID          Name  Absolute Magnitude  Est Dia in KM(min)  \
# count      4.687000e+03  4.687000e+03         4687.000000         4687.000000
# mean       3.272298e+06  3.272298e+06           22.267865            0.204604
# std        5.486011e+05  5.486011e+05            2.890972            0.369573
# min        2.000433e+06  2.000433e+06           11.160000            0.001011
# 25%        3.097594e+06  3.097594e+06           20.100000            0.033462
# 50%        3.514799e+06  3.514799e+06           21.900000            0.110804
# 75%        3.690060e+06  3.690060e+06           24.500000            0.253837
# max        3.781897e+06  3.781897e+06           32.100000           15.579552
#
#        Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# count         4687.000000        4687.000000        4687.000000
# mean             0.457509         204.604203         457.508906
# std              0.826391         369.573402         826.391249
# ...

# %%
# I am going to drop approximated distances in M and Miles  to avoid repetition
columns = ['Est Dia in KM(min)','Est Dia in KM(max)','Est Dia in M(min)','Est Dia in M(max)','Est Dia in Miles(min)','Est Dia in Miles(max)','Est Dia in Feet(min)','Est Dia in Feet(max)']

# %%
df.drop(columns,axis=1,inplace=True)

# %%
new=['Miss Dist.(miles)','Miss Dist.(Astronomical)','Miss Dist.(lunar)', 'Relative Velocity km per hr','Relative Velocity km per sec','Neo Reference ID']
df.drop(new,axis=1,inplace=True)

# %%
df.corr()
# Out:
#                                  Name  Absolute Magnitude  \
# Name                         1.000000            0.602381
# Absolute Magnitude           0.602381            1.000000
# Epoch Date Close Approach    0.186513            0.168621
# Miles per hour              -0.165032           -0.376853
# Miss Dist.(kilometers)      -0.155782           -0.339117
# Orbit ID                    -0.651200           -0.575668
# Orbit Uncertainity           0.611205            0.677764
# Minimum Orbit Intersection  -0.158673           -0.488235
# Jupiter Tisserand Invariant -0.004854            0.238702
# Epoch Osculation             0.006023           -0.116087
# Eccentricity                -0.125071           -0.361359
# Semi Major Axis              0.035865           -0.212437
# Inclination                 -0.175461           -0.459632
# Asc Node Longitude          -0.026381           -0.011470
# Orbital Period               0.040058           -0.206774
# ...

# %%
df['Hazardous'] = df['Hazardous'].replace(to_replace='False',value=0)
df['Hazardous'] = df['Hazardous'].replace(to_replace='True',value=1)

# %%
X=df.drop(['Hazardous','Close Approach Date','Equinox','Orbiting Body','Orbit Determination Date'],axis=1)
y=df['Hazardous']

# %%
"""from sklearn.linear_model import LogisticRegression
rfmodel=LogisticRegression()
rfmodel.fit(X,y)
importance = rfmodel.coef_[0]
feature_importance = {'Features':X,'Coef_Score':importance}
feature_importance = pd.DataFrame(feature_importance)
feature_importance =feature_importance.sort_values(by='Coef_Score',ascending =True)
feature_importance = {'Features':X,'Coef_Score':importance}
plt.barh(y=feature_importance.Features,width = feature_importance.Coef_Score)
plt.title('Bar Chart of Logistic Regression Coefficients as Feature Importance Scores')"""
# Out:
# "from sklearn.linear_model import LogisticRegression\nrfmodel=LogisticRegression()\nrfmodel.fit(X,y)\nimportance = rfmodel.coef_[0]\nfeature_importance = {'Features':X,'Coef_Score':importance}\nfeature_importance = pd.DataFrame(feature_importance)\nfeature_importance =feature_importance.sort_values(by='Coef_Score',ascending =True)\nfeature_importance = {'Features':X,'Coef_Score':importance}\nplt.barh(y=feature_importance.Features,width = feature_importance.Coef_Score)\nplt.title('Bar Chart of Logistic Regression Coefficients as Feature Importance Scores')"

# %%
"""DATA ANALYSIS"""
# Out:
# 'DATA ANALYSIS'

# %%
# Heatmap and ClusterMap
fig = plt.figure(figsize=(15,10))
fig.suptitle("Cluster and Heatmap for our data")
plt.subplot(2,2,1)
sns.heatmap(df.corr())
plt.title("A Heatmap for all our features")
plt.subplot(2,2,2)
sns.clustermap(df.corr())
plt.title("A clustermap for all our features")
# Out:
# Text(0.5, 1.0, 'A clustermap for all our features')

# %%
df['Name'].value_counts().head(10)
# Out:
# 3748472    7
# 3102762    7
# 2277810    6
# 3772993    6
# 3566465    5
# 3117468    5
# 2136818    5
# 3738932    5
# 3608620    5
# 2365449    4
# Name: Name, dtype: int64

# %%
#Analysis of Absolute magnitudes of objects over time
fig=plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.lineplot(x=df[df['Name']==df.Name]['Close Approach Date'],y=df[df['Name']==df.Name]['Absolute Magnitude'])
plt.title('Absolute Magnitude over the years')
plt.subplot(2,2,2)
sns.lineplot(x=df[df['Name']==df.Name]['Close Approach Date'],y=df[df['Name']==df.Name]['Eccentricity'])
plt.title('Eccentricity over the years')
plt.subplot(2,2,3)
sns.lineplot(x=df[df['Name']==df.Name]['Close Approach Date'],y=df[df['Name']==df.Name]['Jupiter Tisserand Invariant'])
plt.title('Jupiter Tisseard over the years')
# Out:
# Text(0.5, 1.0, 'Jupiter Tisseard over the years')

# %%
sns.lineplot(x=df['Close Approach Date'],y=df['Jupiter Tisserand Invariant'])
plt.title('Jupiter Tisserad Invariant for the past years')
# Out:
# Text(0.5, 1.0, 'Jupiter Tisserad Invariant for the past years')

# %%
fig=plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.lineplot(x=df['Close Approach Date'],y=df['Perihelion Distance'])
plt.title('Perihelion distance for the past years')
plt.subplot(2,2,2)
sns.lineplot(x=df['Close Approach Date'],y=df['Aphelion Dist'])
plt.title('Aphelion distance for the past years')
# Out:
# Text(0.5, 1.0, 'Aphelion distance for the past years')

# %%
fig=plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.lineplot(x=df['Close Approach Date'],y=df['Perihelion Distance'])
plt.title('Perihelion distance for the past years')
plt.subplot(2,2,2)
sns.lineplot(x=df['Close Approach Date'],y=df['Aphelion Dist'])
plt.title('Aphelion distance for the past years')
# Out:
# Text(0.5, 1.0, 'Aphelion distance for the past years')

# %%
# How fast are the asteroids moving towards us
fig=plt.figure(figsize=(15,10))
fig.suptitle('How Fast the asteroids are approaching earth')
plt.subplot(2,2,1)
sns.lineplot(x=df['Close Approach Date'],y=df['Miles per hour'])
plt.title('Approach for the past years')
plt.subplot(2,2,2)
sns.lineplot(x=df['Close Approach Date'],y=df['Miss Dist.(kilometers)'])
plt.title('Asteriod  distance to earth  for the past years')
# Out:
# Text(0.5, 1.0, 'Asteriod  distance to earth  for the past years')

# %%
# A function that explains all the relevant info on each column
def do_analysis (column,df=df):
    print(f"The most frequently appearing items are{df[column].value_counts().head(10)}")
    print(f"The least frequently appearing items are{df[column].value_counts().head(10)}")
    print(f"The statistical measures are{df[column].describe()}")

# %%
#for column in df.columns:
    #do_analysis(column=column)

# %%
# SEE HOW MANY ASTEROIDS ARE CONSIDERED HAZARDOUS
df.Hazardous.head()
sns.countplot(x=df.Hazardous)
# Out:
# <AxesSubplot:xlabel='Hazardous', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=101)
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train,y_train)
predictions= model.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,mean_absolute_error
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       784
#         True       0.98      0.99      0.98       154
#
#     accuracy                           0.99       938
#    macro avg       0.99      0.99      0.99       938
# weighted avg       0.99      0.99      0.99       938
#
# [[781   3]
#  [  2 152]]

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
dpredict=dtree.predict(X_test)
print(dpredict[:5])
# Out:
# [False False  True  True False]

# %%
print(classification_report(y_test,dpredict))
print(confusion_matrix(y_test,dpredict))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      1.00       784
#         True       0.97      0.98      0.98       154
#
#     accuracy                           0.99       938
#    macro avg       0.99      0.99      0.99       938
# weighted avg       0.99      0.99      0.99       938
#
# [[780   4]
#  [  3 151]]

# %%
fig=plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.countplot(x=dpredict)
plt.title('A countplot for the  Decision tree predictions')
plt.subplot(2,2,2)
sns.countplot(x=predictions)
plt.title('A countplot for the  R.Forest predictions')
# Out:
# Text(0.5, 1.0, 'A countplot for the  R.Forest predictions')

# %%
from sklearn.svm import SVC
s_model = SVC()
s_model.fit(X_train,y_train)
s_predict=s_model.predict(X_test)
print(classification_report(y_test,s_predict))
print(confusion_matrix(y_test,s_predict))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.84      1.00      0.91       784
#         True       0.00      0.00      0.00       154
#
#     accuracy                           0.84       938
#    macro avg       0.42      0.50      0.46       938
# weighted avg       0.70      0.84      0.76       938
#
# [[784   0]
#  [154   0]]
# C:\Users\EDGAR MUYALE DAVIES\anaconda3\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\EDGAR MUYALE DAVIES\anaconda3\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']} 
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.840 total time=   2.1s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.840 total time=   2.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.840 total time=   2.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.839 total time=   2.5s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.840 total time=   2.4s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.840 total time=   2.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.840 total time=   2.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.840 total time=   2.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.839 total time=   2.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.840 total time=   2.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.840 total time=   2.5s
# ...

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=0.1, gamma=1)

# %%
grid_predictions = grid.predict(X_test)

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.84      1.00      0.91       784
#         True       0.00      0.00      0.00       154
#
#     accuracy                           0.84       938
#    macro avg       0.42      0.50      0.46       938
# weighted avg       0.70      0.84      0.76       938
# C:\Users\EDGAR MUYALE DAVIES\anaconda3\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\EDGAR MUYALE DAVIES\anaconda3\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
fig=plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.countplot(x=dpredict)
plt.title('A countplot for the  Decision tree predictions')
plt.subplot(2,2,2)
sns.countplot(x=predictions)
plt.title('A countplot for the  R.Forest predictions')
fig=plt.figure(figsize=(15,10))
plt.subplot(2,2,3)
sns.countplot(x=s_predict)
plt.title('A countplot for the  SVM predictions')
# Out:
# Text(0.5, 1.0, 'A countplot for the  Grid cross validation predictions')

# %%
# using naive bayes probability
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train,y_train)
nb_pred = nb.predict(X_test)
nb_pred[:5]
# Out:
# array([False, False, False, False, False])

# %%
print(confusion_matrix(y_test,nb_pred))
print('\n')
print(classification_report(y_test,nb_pred))
# Out:
# [[784   0]
#  [154   0]]
#
#
#               precision    recall  f1-score   support
#
#        False       0.84      1.00      0.91       784
#         True       0.00      0.00      0.00       154
#
#     accuracy                           0.84       938
#    macro avg       0.42      0.50      0.46       938
# weighted avg       0.70      0.84      0.76       938
# C:\Users\EDGAR MUYALE DAVIES\anaconda3\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\EDGAR MUYALE DAVIES\anaconda3\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# CONSIDERING ALL THE VARIABLES
