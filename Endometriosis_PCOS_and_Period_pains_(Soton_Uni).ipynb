# %% [markdown]
# The purpose of this project is to study in depth Period pain ,PCOS and Endemtriosis.For a majority of women ,sexual health has never been taught to them .In Africa Period stigma stymies all of the efforts to ensure awareness on period pains and hygiene.The data was found from a survey by the University of Soton.I hope this project will shed some light on this problem

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Datasets\Endemetriosis\\Quantitative_Survevy_Data_Set.csv")

# %%
df.head()
# Out:
#   Age School_Year Age@Menarche  \
# 0  17     College           13
# 1  13      Year 9       #NULL!
# 2  17     College           13
# 3  14      Year 9           11
# 4  16     Year 12           12
#
#   How_many_days_ago_did_you_finish_your_last_period           \
# 0                                                20  Regular
# 1                                            #NULL!  Regular
# 2                                                29  Regular
# 3                                                 3  Regular
# 4                                                16  Regular
#
#   Indicate_the_heaviness_of_your_bleeding  \
# 0                                   Heavy
# 1                                  Medium
# 2                                   Heavy
# 3                                  Medium
# 4                                  Medium
#
#   Do_you_miss_school_because_of_your_periods  \
# 0                                         No
# 1                                         No
# ...

# %%
plt.hist(df['Age'])
plt.title('How Age is distributed in our dataset')
plt.show()

# %%
df.isnull().sum().sort_values(ascending=True)
# Out:
# Age                                              0
# Anx_terrified                                    0
# Anx_mixed_up                                     0
# Anx_cheerful                                     0
# Fam_planning_activities_is_difiicult             0
#                                                 ..
# QoL_trouble_getting_along_with_others            0
# QoL_other_teens_will_not_want_to_be_my_friend    0
# QoL_other_teens_will_tease_me                    0
# QoL_its_hard_to_keep_up_with_peers               0
# ZHRQoL                                           0
# Length: 197, dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#     Age School_Year Age@Menarche  \
# 0    17     College           13
# 1    13      Year 9       #NULL!
# 2    17     College           13
# 3    14      Year 9           11
# 4    16     Year 12           12
# ..   ..         ...          ...
# 328  15     Year 11           14
# 329  16     Year 11           10
# 330  15     Year 11           14
# 331  16     Year 11           12
# 332  16     Year 11           12
#
#     How_many_days_ago_did_you_finish_your_last_period             \
# 0                                                  20    Regular
# 1                                              #NULL!    Regular
# 2                                                  29    Regular
# 3                                                   3    Regular
# 4                                                  16    Regular
# ..                                                ...        ...
# 328                                            #NULL!  Irregular
# ...

# %%
df.drop(['What_is_it_about_periods_that_causes_you_to_miss_school5'],axis=1,inplace=True)

# %%
df
# Out:
#     Age School_Year Age@Menarche  \
# 0    17     College           13
# 1    13      Year 9       #NULL!
# 2    17     College           13
# 3    14      Year 9           11
# 4    16     Year 12           12
# ..   ..         ...          ...
# 328  15     Year 11           14
# 329  16     Year 11           10
# 330  15     Year 11           14
# 331  16     Year 11           12
# 332  16     Year 11           12
#
#     How_many_days_ago_did_you_finish_your_last_period             \
# 0                                                  20    Regular
# 1                                              #NULL!    Regular
# 2                                                  29    Regular
# 3                                                   3    Regular
# 4                                                  16    Regular
# ..                                                ...        ...
# 328                                            #NULL!  Irregular
# ...

# %%
sns.histplot(df['Age@Menarche'])
plt.title('How Age at Menarch is distributed')
plt.show()

# %%
df['Age@Menarche'].value_counts().head(20)
# Many women start experiencing periods at the age of 12 years according to our datasets
# Out:
# 12        114
# 13         81
# 11         64
# 10         35
# 14         18
# 9           8
# 15          8
# #NULL!      4
# 1           1
# Name: Age@Menarche, dtype: int64

# %%
fig = plt.figure(figsize=(15,8))
sns.countplot(x= df['School_Year'])
plt.title('School Year distribution in our dataset')
plt.show()
# A lot of the women are at Year 9 and Year 12 in their school life

# %% [markdown]
# # Period pains ,Period patterns and their social and mental  impacts

# %% [markdown]
# I'd like to suppose that a girl who has missed her period,or has irregular periods is pretty bumped about it. Second case is a girl who has very painful periods and she thinks its normal. There is not enough information about excessive period pain being a  likely indication of PCOS or Endometriosis or PID.So the girl wanders whats wrong and at this point she fails to recognise that one of her relatives has once had endometriosis.So she gets depressed,her productivity wavers,her social life seems to get down the drains. This I can visualize.

# %% [markdown]
# # General School Attendance during that 'time of the month' as it is always talked of

# %%
plt.figure(figsize=(20,8))
sns.countplot(x = df['Do_you_miss_school_because_of_your_periods'])
plt.title('General school attendance during monthly period')
plt.show()
#  A majority of women attend school during their monthly period,but some miss with some period

# %%
sns.countplot(x=df['Indicate_the_heaviness_of_your_bleeding'])
plt.title('Heaviness of bleeding during periods')
plt.show()
# A majority of women have a medium bleeding ,which can be a good sign

# %%
plt.figure(figsize=(20,8))
sns.countplot(x= df[df['Do_you_miss_school_because_of_your_periods']=='Yes-every period']['If_yes_how_many_days_do_you_usually_stay_home_for'])
plt.xlabel('No of days ')
plt.title('How many days off school due to periods')
plt.show()
# Most miss a day off school

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle('Reasons for women who miss school during their periods')
plt.subplot(2,2,1)
sns.countplot(x= df[df['Do_you_miss_school_because_of_your_periods']=='Yes-every period']['What_is_it_about_periods_that_causes_you_to_miss_school1'])
plt.xlabel('Reasons ')
plt.title('What is it about periods that makes them miss school')
plt.subplot(2,2,2)
sns.countplot(x= df[df['Do_you_miss_school_because_of_your_periods']=='Yes-every period']['What_is_it_about_periods_that_causes_you_to_miss_school2'])
plt.xlabel('Reasons ')
plt.title('What is it about periods that makes them miss school2')
plt.subplot(2,2,3)
sns.countplot(x= df[df['Do_you_miss_school_because_of_your_periods']=='Yes-every period']['What_is_it_about_periods_that_causes_you_to_miss_school3'])
plt.xlabel('Reasons ')
plt.subplot(2,2,4)
sns.countplot(x= df[df['Do_you_miss_school_because_of_your_periods']=='Yes-every period']['What_is_it_about_periods_that_causes_you_to_miss_school4'])
plt.xlabel('Reasons ')
plt.show()

# %% [markdown]
# # Period pain  and Medication

# %%
plt.figure(figsize=(20,8))
plt.subplot(2,2,1)
sns.countplot(x= df['If_you_have_period_pain_do_you_take_medication'])
plt.title('Period pain and medication')
plt.subplot(2,2,2)
sns.countplot(x= df['How_effective_are_the_medications_at_relieving_the_pain'])
plt.title('Medication effectivenes in  period pain')
plt.show()
# Medicine helps during the periods based on the rating  by the respondents

# %%
fig= plt.figure(figsize=(20,8))
fig.suptitle('Medications taken during Period Pain')
plt.subplot(2,2,1)
sns.countplot(x= df['If_yes_which_medications1'])
plt.title('Period pain and medication1')
plt.subplot(2,2,2)
sns.countplot(x= df['If_yes_which_medications2'])
plt.title('Period pain and medication2')
plt.subplot(2,2,3)
sns.countplot(x= df['If_yes_which_medications3'])
plt.title('Period pain and medication3')
plt.subplot(2,2,4)
sns.countplot(x= df['If_yes_which_medications1'])
plt.title('Period pain and medication4')
plt.show()
# Nurofen  and  Aspirin are the most preffered of he drugs

# %%
df.columns[:20]
# Out:
# Index(['Age', 'School_Year', 'Age@Menarche',
#        'How_many_days_ago_did_you_finish_your_last_period', ' ',
#        'Indicate_the_heaviness_of_your_bleeding',
#        'Do_you_miss_school_because_of_your_periods',
#        'If_yes_how_many_days_do_you_usually_stay_home_for',
#        'What_is_it_about_periods_that_causes_you_to_miss_school1',
#        'What_is_it_about_periods_that_causes_you_to_miss_school2',
#        'What_is_it_about_periods_that_causes_you_to_miss_school3',
#        'What_is_it_about_periods_that_causes_you_to_miss_school4',
#        'If_you_have_period_pain_do_you_take_medication',
#        'If_yes_which_medications1', 'If_yes_which_medications2',
#        'If_yes_which_medications3', 'If_yes_which_medications4',
#        'How_effective_are_the_medications_at_relieving_the_pain', 'Nausea',
#        'Vomiting'],
#       dtype='object')

# %%
df.columns[40:50]
# Out:
# Index(['Headaches', 'Thrush', 'Dizziness_fainting_passingout',
#        'Feeling_down_depressed', 'Diagnosed_with_PCOS',
#        'Diagnosed_with_Endometriosis', 'Diagnosed_with_PID',
#        'Mum_or_sister_with_period_problems',
#        'Mum_or_sister_with_severe_period_pain', 'Mum_or_sister_with_PID'],
#       dtype='object')

# %% [markdown]
# # Period patterns

# %%
#df[df['Over_the_past_three_months_have_your_periods_been']=='Regular']

# %% [markdown]
# # IRREGULAR PERIOD PATTERNS,A more focused approach

# %%
#How many have Regular periods and miss school?
plt.figure(figsize=(20,8))
sns.countplot(x=df[df['Over_the_past_three_months_have_your_periods_been']=='Regular']['Do_you_miss_school_because_of_your_periods'])
plt.title('School attendance with Regular periods')
plt.show()

# %%
sns.histplot(df[df['Over_the_past_three_months_have_your_periods_been']=='Irregular']['Age'])
plt.show('Age distribution of Women with Irregular periods')
plt.show()
# 16 years seems to be the age that some girls/women have irregular periods

# %%
# How many have irregular periods and miss school?
plt.figure(figsize=(20,8))
sns.countplot(x=df[df['Over_the_past_three_months_have_your_periods_been']=='Irregular']['Do_you_miss_school_because_of_your_periods'])
plt.title('School attendance inspite of irregular periods')
plt.show()

# %%
df.columns[:30]

# %%
plt.figure(figsize=(20,8))
fig.suptitle('Which symptoms are prevalent in those that skip school')
plt.subplot(2,2,1)
sns.countplot(x=df[df['Do_you_miss_school_because_of_your_periods']=='Yes-every period']['Aching_outside_vagina'])
plt.title('1st symptom :Aching outside vagina')
plt.subplot(2,2,2)
sns.countplot(x=df[df['Do_you_miss_school_because_of_your_periods']=='Yes-every period']['Nausea'])
plt.title('3rd symptom :Nausea')
plt.subplot(2,2,3)
sns.countplot(x=df[df['Do_you_miss_school_because_of_your_periods']=='Yes-every period']['Bloating'])
plt.title('2nd  symptom :Bloating')
plt.subplot(2,2,4)
sns.countplot(x=df[df['Do_you_miss_school_because_of_your_periods']=='Yes-every period']['Aching_down_legs'])
plt.title('1st symptom :Aching down legs')
plt.show()
# Almost every girl that misses school during their periods do so because of Aching_outside_vagina,Bloating,Aching_down_legs
# Could this be because of PCOS OR Endometriosis or PID?

# %%
df.columns[40:50]
# Out:
# Index(['Headaches', 'Thrush', 'Dizziness_fainting_passingout',
#        'Feeling_down_depressed', 'Diagnosed_with_PCOS',
#        'Diagnosed_with_Endometriosis', 'Diagnosed_with_PID',
#        'Mum_or_sister_with_period_problems',
#        'Mum_or_sister_with_severe_period_pain', 'Mum_or_sister_with_PID'],
#       dtype='object')

# %% [markdown]
# # ENDOMETRIOSIS ,PID AND ENDOMETRIOSIS AS A FACTOR

# %%
# How many are diagonised with Endometriosis
df['Diagnosed_with_Endometriosis'].value_counts().head(10)
# Out:
# No            293
# Don't know     29
# Yes             7
# #NULL!          4
# Name: Diagnosed_with_Endometriosis, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(x= df['Diagnosed_with_Endometriosis'])
plt.title('Endometreosis diagnosis')
plt.show()

# %%
# How many are Diagnosed with PCOS
df['Diagnosed_with_PCOS'].value_counts().head(6)
# Out:
# No            287
# Don't know     27
# Yes            14
# #NULL!          4
# 4               1
# Name: Diagnosed_with_PCOS, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(x= df['Diagnosed_with_PCOS'])
plt.title('PCOS diagnosis by numbers')
plt.show()

# %%
# How many are Diagnosed with PID
df['Diagnosed_with_PID'].value_counts().head(10)
# Out:
# No            291
# Don't know     27
# Yes            12
# #NULL!          3
# Name: Diagnosed_with_PID, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(x= df['Diagnosed_with_PCOS'])
plt.title('PCOS diagnosis')
plt.show()

# %% [markdown]
# #     What are the common symptoms experienced by women diagnosed with the three Diseases?

# %% [markdown]
# # Endometriosis

# %%
df[df['Diagnosed_with_Endometriosis']=='Yes']
# Out:
#     Age School_Year Age@Menarche  \
# 193  17     Year 12           12
# 201  17     Year 12           13
# 206  14     College           12
# 208  17     College           15
# 209  16     College           12
# 211  17     College           14
# 217  16     College           11
#
#     How_many_days_ago_did_you_finish_your_last_period             \
# 193                                                 0  Irregular
# 201                                                40  Irregular
# 206                                                 1    Regular
# 208                                                32  Irregular
# 209                                                 2    Regular
# 211                                                15    Regular
# 217                                                16  Irregular
#
#     Indicate_the_heaviness_of_your_bleeding  \
# 193                                  Medium
# 201                                   Heavy
# ...

# %%
plt.figure(figsize=(20,8))
sns.histplot(df[df['Diagnosed_with_Endometriosis']=='Yes']['Age@Menarche'])
plt.grid()
plt.title("The distribution for Menarch ages for women with Endometreosis")
plt.show()
# A majority of them have their first periods at age 12

# %%
# create a current age column
type(df['Age@Menarche'].values)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize=(15,8))
sns.histplot(x =df[df['Diagnosed_with_Endometriosis']=='Yes']['Age'],color='black')
plt.title('Current years for Endometreosis diagnosis')
plt.grid()
plt.show()
# Current age stands at 17 years ,so they have lived 5 years with the diagnosis of Endometriosis

# %%
# Is PCOS inherited ,are genses the most causes?
df[df['Diagnosed_with_Endometriosis']=='Yes'].columns[35:55]
# Out:
# Index(['Feeling_urgent_need_to_empty_bowels', 'Bleeding_from_your_bottom',
#        'Pain_during_or_after_sexual_intercourse', 'Need_to_pass_urine_often',
#        'Feeling_really_tired', 'Headaches', 'Thrush',
#        'Dizziness_fainting_passingout', 'Feeling_down_depressed',
#        'Diagnosed_with_PCOS', 'Diagnosed_with_Endometriosis',
#        'Diagnosed_with_PID', 'Mum_or_sister_with_period_problems',
#        'Mum_or_sister_with_severe_period_pain', 'Mum_or_sister_with_PID',
#        'Mum_or_sister_with_PCOS', 'Mum_or_sister_with_Endometriosis',
#        'VASusual', 'VASrec', 'QoL_hard_to_walk_more_than_one_block'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Mum_or_sister_with_Endometriosis'])
plt.title('How many with Endometriosis have Endometriosis')
plt.show()
# Seems like a majority of their parents do not have endometriosis,but since those that do not know are a number we cant rule that out

# %%
# Maybe  if we look at the period pains we can try to hypothesize whether they have endometriosis
plt.figure(figsize=(20,8))
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Mum_or_sister_with_period_problems'])
plt.title('How many have mothers and sisters experiencing severe period pain?')
plt.show()

# %%
df[df['Diagnosed_with_Endometriosis']=='Yes']['Mum_or_sister_with_period_problems']
# The results shed on light on our earlier on hypothesis
# Out:
# 193           Yes
# 201           Yes
# 206        #NULL!
# 208            No
# 209    Don't know
# 211    Don't know
# 217            No
# Name: Mum_or_sister_with_period_problems, dtype: object

# %%
# How about severe period pain,this is a high indication of endometriosis
df[df['Diagnosed_with_Endometriosis']=='Yes']['Mum_or_sister_with_Endometriosis']
# A majority claimed that No their parents had no endemetriosis ,but also Most dont know
# Out:
# 193            No
# 201            No
# 206    Don't know
# 208            No
# 209    Don't know
# 211    Don't know
# 217            No
# Name: Mum_or_sister_with_Endometriosis, dtype: object

# %%
plt.figure(figsize=(20,8))
sns.countplot(x = df[df['Diagnosed_with_Endometriosis']=='Yes']['Mum_or_sister_with_Endometriosis'])
plt.grid()
plt.title('Mum or sister with severe period pains for Endometriosis')
plt.show()

# %% [markdown]
# COMMON SYMPTOMS FOR ENDOMETRIOSIS: Can we predict endemetriosis given the symptoms?

# %%
df[df['Diagnosed_with_Endometriosis']=='Yes'].columns[32:44]
# I will use these symptoms to try to create a model using Endometriosis ,in an ensemble manner
# Out:
# Index(['Pain_when_your_bladder_is_full', 'Pain_before_or_when_passing_wind',
#        'Pain_when_emptying_your_bowels', 'Feeling_urgent_need_to_empty_bowels',
#        'Bleeding_from_your_bottom', 'Pain_during_or_after_sexual_intercourse',
#        'Need_to_pass_urine_often', 'Feeling_really_tired', 'Headaches',
#        'Thrush', 'Dizziness_fainting_passingout', 'Feeling_down_depressed'],
#       dtype='object')

# %% [markdown]
# #

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle("Endometriosis Symptoms a custom model : Bowels ")
plt.subplot(2,2,1)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Pain_when_your_bladder_is_full'])
plt.subplot(2,2,2)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Pain_before_or_when_passing_wind'])
plt.subplot(2,2,3)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Pain_when_emptying_your_bowels'])
plt.subplot(2,2,4)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Feeling_urgent_need_to_empty_bowels'])
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle("Endometriosis Symptoms a custom model : Lethargy and Fatigue ")
plt.subplot(2,2,1)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Bleeding_from_your_bottom'])
plt.subplot(2,2,2)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Pain_during_or_after_sexual_intercourse'])
plt.subplot(2,2,3)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Need_to_pass_urine_often'])
plt.subplot(2,2,4)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Feeling_really_tired'])
plt.grid()
plt.show()
# Feeling tired seems to be the first major symptom or indication of Endometriosis

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle("Endometriosis Symptoms a custom model : Headaches and Dizziness ")
plt.subplot(2,2,1)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Headaches'])
plt.subplot(2,2,2)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Thrush'])
plt.subplot(2,2,3)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Dizziness_fainting_passingout'])
plt.subplot(2,2,4)
sns.countplot(x=df[df['Diagnosed_with_Endometriosis']=='Yes']['Feeling_down_depressed'])
plt.grid()
plt.show()

# %%
# Based on the above results ,aside from tiredness ,other common symptoms include headaches,diziness,feeling depressed

# %% [markdown]
# # PCOS :Poly Cystic Ovary Syndrome

# %%
df[df['Diagnosed_with_PCOS']=='Yes']
# Out:
#     Age School_Year Age@Menarche  \
# 6    18     College           12
# 9    17     College           12
# 179  13      Year 9           11
# 193  17     Year 12           12
# 200  17     Year 12           13
# 201  17     Year 12           13
# 202  17     Year 12           11
# 209  16     College           12
# 212  17     College           12
# 217  16     College           11
# 218  17     College           12
# 250  18       Other           13
# 251  17       Other           10
# 299  15     Year 11           11
#
#     How_many_days_ago_did_you_finish_your_last_period             \
# 6                                                   6  Irregular
# 9                                                 365  Irregular
# 179                                                 0  Irregular
# 193                                                 0  Irregular
# 200                                                15    Regular
# ...

# %%
plt.figure(figsize=(20,8))
sns.histplot(df[df['Diagnosed_with_PCOS']=='Yes']['Age@Menarche'])
plt.grid()
plt.title("The distribution for Menarch ages for women with PCOS")
plt.show()
# A majority of them have their first periods at age 12

# %%
plt.figure(figsize=(15,8))
sns.histplot(x =df[df['Diagnosed_with_Endometriosis']=='Yes']['Age'],color='red')
plt.title('Current years for PCOS diagnosis')
plt.grid()
plt.show()
# Seems that 17 years is the modal for our case studies

# %%
# Maybe  if we look at the period pains we can try to hypothesize whether they have PCOS
plt.figure(figsize=(20,8))
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Mum_or_sister_with_period_problems'])
plt.title('How many have mothers and sisters experiencing severe period pain?')
plt.show()
# A majority claimed  to have sister who complained about having severe period pains .Lets see if they have

# %%
plt.figure(figsize=(20,8))
sns.countplot(x = df[df['Diagnosed_with_PCOS']=='Yes']['Mum_or_sister_with_PCOS'])
plt.grid()
plt.title('Mum or sister with severe period pains for PCOS diagnosed')
plt.show()
# While a majority claimed No,a good number said that Yes ,their parents have PCOS diagnosis a good sign

# %% [markdown]
# COMMON SYMPTOMS FOR PCOS

# %%
df[df['Diagnosed_with_PCOS']=='Yes'].columns[32:44]
# I will use these symptoms to try to create a model using PCOS ,in an ensemble manner
# Out:
# Index(['Pain_when_your_bladder_is_full', 'Pain_before_or_when_passing_wind',
#        'Pain_when_emptying_your_bowels', 'Feeling_urgent_need_to_empty_bowels',
#        'Bleeding_from_your_bottom', 'Pain_during_or_after_sexual_intercourse',
#        'Need_to_pass_urine_often', 'Feeling_really_tired', 'Headaches',
#        'Thrush', 'Dizziness_fainting_passingout', 'Feeling_down_depressed'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle("PCOS Symptoms a custom model : Bowels ")
plt.subplot(2,2,1)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Pain_when_your_bladder_is_full'])
plt.subplot(2,2,2)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Pain_before_or_when_passing_wind'])
plt.subplot(2,2,3)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Pain_when_emptying_your_bowels'])
plt.subplot(2,2,4)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Feeling_urgent_need_to_empty_bowels'])
plt.grid()
plt.show()
#Pain when bladder is full and pain whe emptying bowels are the main indicators

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle("PCOS Symptoms a custom model : Lethargy and Fatigue ")
plt.subplot(2,2,1)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Bleeding_from_your_bottom'])
plt.subplot(2,2,2)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Pain_during_or_after_sexual_intercourse'])
plt.subplot(2,2,3)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Need_to_pass_urine_often'])
plt.subplot(2,2,4)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Feeling_really_tired'])
plt.grid()
plt.show()
# Feeling very tired is one of the main symptoms in this category

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle("PCOS Symptoms a custom model : Headaches and Dizziness ")
plt.subplot(2,2,1)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Headaches'])
plt.subplot(2,2,2)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Thrush'])
plt.subplot(2,2,3)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Dizziness_fainting_passingout'])
plt.subplot(2,2,4)
sns.countplot(x=df[df['Diagnosed_with_PCOS']=='Yes']['Feeling_down_depressed'])
plt.grid()
plt.show()

# %% [markdown]
#  Dizzines ,headaches ,feeling depressed ,feeling tired ,pain when bladder is full and pain when emptying bowels
#  are the major  PCOS symptoms according to this ensemble model

# %% [markdown]
# # SOCIAL IMPACTS OF ENDOMETRIOSIS AND PCOS
# I am going to study the social impact of Endometriosis and PCOS ,on Anxiety,Depression and Not attending school.I have indexed them so that identifying each trait becomes easy

# %% [markdown]
# # Depression as A result of PCOS diagnosis

# %%
depression = df[df['Diagnosed_with_PCOS']=='Yes'].columns[180:]
pcos = df[df['Diagnosed_with_PCOS']=='Yes']

# %%
depression
# Out:
# Index(['StateAnx', 'TraitAnx', 'HRQoL', 'DepTot', 'AnxTot', 'FamTot',
#        'CatasTot', 'SomatTot', 'ZVASusual', 'ZVASrec', 'ZSomatTot',
#        'ZCatasTot', 'ZFamTot', 'ZAnxTot', 'ZDepTot', 'ZHRQoL'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle('Depression among women living with PCOS ')
plt.subplot(2,2,1)
sns.countplot(x=pcos['Dep_Item1'])
plt.subplot(2,2,2)
sns.countplot(x=pcos['Dep_item2'])
plt.subplot(2,2,3)
sns.countplot(x=pcos['Dep_item3'])
plt.subplot(2,2,4)
sns.countplot(x=pcos['Dep_item4'])
plt.show()
#

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle('Depression among women living with PCOS ')
plt.subplot(2,2,1)
sns.countplot(x=pcos['Dep_item5'])
plt.subplot(2,2,2)
sns.countplot(x=pcos['Dep_item6'])
plt.subplot(2,2,3)
sns.countplot(x=pcos['Dep_item7'])
plt.subplot(2,2,4)
sns.countplot(x=pcos['Dep_item8'])
plt.show()
# They claim to feel like crying once in a while ,things bother them many times ,they claim to feel alone many times

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle('Depression among women living with PCOS ')
plt.subplot(2,2,1)
sns.countplot(x=pcos['Dep_item9'])
plt.subplot(2,2,2)
sns.countplot(x=pcos['Dep_item10'])
plt.show()
# They claim to have plenty of friends but they are unsure  if somebody loves them

# %% [markdown]
# """There are so many downsides to having  been diagnosed with PCOS  which include depression,
# A majority claim to feel sad once in a while,they claim not be sure if things will work out,and they do not like themselves,
# They claim to feel like crying once in a while ,things bother them many times ,they feel alone many times
# Those diagnosed with PCOS claim to have  plenty of friends but they are unsure  if somebody loves them . There seems to be too
# much stigma ,that leaves these women vulnerable to the idea of not being to coexist with their friends
# """

# %% [markdown]
# # Anxiety as A result of PCOS diagnosis

# %%
df[df['Diagnosed_with_PCOS']=='Yes'].columns[88:106]
# Out:
# Index(['Anx_I_feel_like_crying', 'Anx_I_feel_unhappy',
#        'Anx_I_have_trouble_making_up_my_mind',
#        'Anx_it_is_difficult_for_me_to_face_my_problems',
#        'Anx_I_worry_too_much', 'Anx_I_get_upset_at_home', 'Anx_I_am_shy',
#        'Anx_I_feel_troubled',
#        'Anx_unimportant_thoughts_run_through_my_mind_and_bother_me',
#        'Anx_I_worry_about_school', 'Anx_I_have_trouble_deciding_what_to_do',
#        'Anx_I_notice_my_heart_beats_fast', 'Anx_I_am_secretly_afraid',
#        'Anx_I_worry_about_my_parents', 'Anx_my_hands_get_sweaty',
#        'Anx_I_worry_about_things_that_may_happen',
#        'Anx_it_is_hard_for_me_to_fall_asleep_at_night',
#        'Anx_I_get_a_funny_feeling_in_my_stomach'],
#       dtype='object')

# %%
fig=plt.figure(figsize=(20,8))
plt.suptitle('Anxiety factor due to PCOS')
plt.subplot(2,2,1)
sns.countplot(x = pcos['Anx_I_feel_like_crying'])
plt.subplot(2,2,2)
sns.countplot(x = pcos['Anx_I_feel_unhappy'])
plt.subplot(2,2,3)
sns.countplot(x = pcos['Anx_I_have_trouble_making_up_my_mind'])
plt.subplot(2,2,4)
sns.countplot(x = pcos['Anx_I_worry_too_much'])
plt.tight_layout()
plt.show()

# %%
fig=plt.figure(figsize=(20,8))
plt.suptitle('Anxiety factor due to PCOS')
plt.subplot(2,2,1)
sns.countplot(x = pcos['Anx_unimportant_thoughts_run_through_my_mind_and_bother_me'])
plt.subplot(2,2,2)
sns.countplot(x = pcos['Anx_I_worry_about_things_that_may_happen'])
plt.subplot(2,2,3)
sns.countplot(x = pcos['Anx_I_get_a_funny_feeling_in_my_stomach'])
plt.subplot(2,2,4)
sns.countplot(x = pcos['Anx_I_have_trouble_deciding_what_to_do'])
plt.tight_layout()
plt.show()

# %% [markdown]
# PCOS causes Anxiety and the impact in ways such as , Sometimes they feel like crying,they feel unhappy,they have trouble
# making up their minds  and often worry too much
# They claimed to sometimes have unimportant thoughts running through their  minds,worry about things that may happen,have trouble deciding what to do
# Sometimes they had a funny feeling in their stomachs

# %% [markdown]
# # Endometriosis social impacts : Anxiety and Depression

# %%
endom = df[df['Diagnosed_with_Endometriosis']=='Yes']
endom
# Out:
#     Age School_Year Age@Menarche  \
# 193  17     Year 12           12
# 201  17     Year 12           13
# 206  14     College           12
# 208  17     College           15
# 209  16     College           12
# 211  17     College           14
# 217  16     College           11
#
#     How_many_days_ago_did_you_finish_your_last_period             \
# 193                                                 0  Irregular
# 201                                                40  Irregular
# 206                                                 1    Regular
# 208                                                32  Irregular
# 209                                                 2    Regular
# 211                                                15    Regular
# 217                                                16  Irregular
#
#     Indicate_the_heaviness_of_your_bleeding  \
# 193                                  Medium
# 201                                   Heavy
# ...

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle('Depression among women living with Endometriosis ')
plt.subplot(2,2,1)
sns.countplot(x=endom['Dep_Item1'])
plt.subplot(2,2,2)
sns.countplot(x=endom['Dep_item2'])
plt.subplot(2,2,3)
sns.countplot(x=endom['Dep_item3'])
plt.subplot(2,2,4)
sns.countplot(x=endom['Dep_item4'])
plt.show()

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle('Depression among women living with Endometriosis ')
plt.subplot(2,2,1)
sns.countplot(x=endom['Dep_item5'])
plt.subplot(2,2,2)
sns.countplot(x=endom['Dep_item6'])
plt.subplot(2,2,3)
sns.countplot(x=endom['Dep_item7'])
plt.subplot(2,2,4)
sns.countplot(x=endom['Dep_item8'])
plt.show()

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle('Depression among women living with Endometriosis ')
plt.subplot(2,2,1)
sns.countplot(x=endom['Dep_item9'])
plt.subplot(2,2,2)
sns.countplot(x=endom['Dep_item10'])
plt.show()

# %% [markdown]
# As with PCOS the women feel like like crying all the time and they feel alone most of the time.In both cases they feel like that
# things will not work out okay.A clear indication that endemetreosis leads to depression.

# %% [markdown]
# Endometriosis :Anxiety

# %%
fig=plt.figure(figsize=(20,8))
plt.suptitle('Anxiety factor due to Endometriosis')
plt.subplot(2,2,1)
sns.countplot(x = endom['Anx_I_feel_like_crying'])
plt.subplot(2,2,2)
sns.countplot(x = endom['Anx_I_feel_unhappy'])
plt.subplot(2,2,3)
sns.countplot(x = endom['Anx_I_have_trouble_making_up_my_mind'])
plt.subplot(2,2,4)
sns.countplot(x = endom['Anx_I_worry_too_much'])
plt.tight_layout()
plt.show()

# %% [markdown]
# When diagnosed with Endometreosis ,the women feel like crying sometimes and feel unhappy. This disease makes them have trouble making up their minds and worry too much

# %% [markdown]
# # QUALITY OF LIFE CHANGE DUE TO PCOS AND ENDOMETREOSIS

# %%
pcos.columns[170:]
# Out:
# Index(['SOM_blurred_vision', 'SOM_vomiting', 'SOM_bloated_or_gassy',
#        'SOM_food_making_you_sick', 'SOM_pain_in_joints',
#        'SOM_pain_in_arms_or_legs', 'QoLPhs', 'QoLEmot', 'QoLSoc', 'QoLSchl',
#        'StateAnx', 'TraitAnx', 'HRQoL', 'DepTot', 'AnxTot', 'FamTot',
#        'CatasTot', 'SomatTot', 'ZVASusual', 'ZVASrec', 'ZSomatTot',
#        'ZCatasTot', 'ZFamTot', 'ZAnxTot', 'ZDepTot', 'ZHRQoL'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20,8))
plt.suptitle('QUALITY OF LIFE CHANGE DUE TO PCOS DIAGNOSIS')
plt.subplot(2,2,1)
sns.countplot(x=pcos['QoLPhs'])
plt.subplot(2,2,2)
sns.countplot(x=pcos['QoLEmot'])
plt.subplot(2,2,3)
sns.countplot(x=pcos['QoLSoc'])
plt.subplot(2,2,4)
sns.countplot(x=pcos['QoLSchl'])
plt.show()

# %%
fig = plt.figure(figsize=(20,8))
plt.suptitle('QUALITY OF LIFE CHANGE DUE TO ENDOMETREOSIS DIAGNOSIS')
plt.subplot(2,2,1)
sns.countplot(x=endom['QoLPhs'])
plt.subplot(2,2,2)
sns.countplot(x=endom['QoLEmot'])
plt.subplot(2,2,3)
sns.countplot(x=endom['QoLSoc'])
plt.subplot(2,2,4)
sns.countplot(x=endom['QoLSchl'])
plt.show()

# %% [markdown]
# # THE END : THANK YOU
